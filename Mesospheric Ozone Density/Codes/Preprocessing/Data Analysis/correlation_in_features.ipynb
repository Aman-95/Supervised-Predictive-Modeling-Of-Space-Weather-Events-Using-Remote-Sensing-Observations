# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f=pd.read_csv("C:\\Users\\Acer\\PycharmProjects\\BTech_Project\\final_dataset_1.csv")
df=pd.DataFrame(f)
df
# Out:
#         event  solAp  solKp  solf10p7Daily      time  tpaltitude  tplatitude  \
# 0           3      4    3.0          141.2   2263028   82.596191   14.750739
# 1           3      4    3.0          141.2   2262984   82.219543   14.749823
# 2           3      4    3.0          141.2   2262939   81.842575   14.748901
# 3           3      4    3.0          141.2   2262894   81.465485   14.747980
# 4           3      4    3.0          141.2   2262849   81.088287   14.747014
# ...       ...    ...    ...            ...       ...         ...         ...
# 220292     96     24    4.3           94.9  89659540   80.539856    4.825286
# 220293     96     24    4.3           94.9  89659584   80.162437    4.829841
# 220294     96     24    4.3           94.9  89659629   79.784912    4.834395
# 220295     96     24    4.3           94.9  89659673   79.407272    4.838956
# 220296     96     24    4.3           94.9  89659719   79.029518    4.843551
#
#         tplongitude  tpSolarZen       ktemp  dst_index  ae_index  sym_h  \
# 0          7.603207  159.596435  198.523544          6        11     12
# 1          7.594763  159.604645  199.787384          6        11     12
# 2          7.586319  159.612869  201.256927          6        11     12
# 3          7.577875  159.621078  202.794830          6        11     12
# 4          7.569425  159.629303  204.287201          6        11     12
# ...             ...         ...         ...        ...       ...    ...
# 220292   340.257812  166.911957  193.352264        -64       118    -63
# 220293   340.250549  166.915314  190.949905        -64       118    -63
# 220294   340.243286  166.918671  190.055206        -64       118    -63
# 220295   340.236054  166.922028  190.625885        -64       118    -63
# 220296   340.228790  166.925415  192.019409        -64       118    -63
#
#           O3_density       density         O3_96 O3_127
# 0       3.109997e+08  2.030000e+14  1.530000e-06     --
# 1       2.709888e+08  2.140000e+14  1.260000e-06     --
# 2       2.382119e+08  2.270000e+14  1.050000e-06     --
# 3       2.135905e+08  2.390000e+14  8.930000e-07     --
# 4       1.970450e+08  2.530000e+14  7.800000e-07     --
# ...              ...           ...           ...    ...
# 220292  2.532214e+07  2.960000e+14  8.570000e-08     --
# 220293  1.252721e+07  3.190000e+14  3.920000e-08     --
# 220294  1.270673e+07  3.430000e+14  3.710000e-08     --
# 220295  1.917510e+07  3.650000e+14  5.250000e-08     --
# 220296  2.955099e+07  3.870000e+14  7.640000e-08     --
#
# [220297 rows x 17 columns]

# %%
L=[]
for col1 in df.columns:
    if col1 in ["O3_127","density","O3_96"]:
        continue
    l=[]
    for col2 in df.columns:
        if col2 in ["O3_127","density","O3_96"]:
            continue
        c=df[f"{col1}"].corr(df[f"{col2}"])
        l.append(c)
    L.append(l)

# %%
Dic={"0":"event","1":"solAp","2":"solKp","3":"solf10p7Daily","4":"time",
     "5":"tpaltitude","6":"tplatitude","7":"tplongitude","8":"tpSolarZen","9":"ktemp",
    "10":"dst_index","11":"ae_index","12":"sym_h","13":"O3_density"}

# %%
df2=pd.DataFrame(L,index=list(Dic.values()),columns=list(Dic.values()))
df2
# Out:
#                event  solAp  solKp solf10p7Daily   time tpaltitude tplatitude  \
# event           1.00   0.00   0.00         -0.00   0.06      -0.18      -0.76
# solAp           0.00   1.00   0.79         -0.16  -0.03      -0.01       0.00
# solKp           0.00   0.79   1.00         -0.22  -0.04      -0.01      -0.00
# solf10p7Daily  -0.00  -0.16  -0.22          1.00  -0.00       0.00      -0.00
# time            0.06  -0.03  -0.04         -0.00   1.00       0.02      -0.05
# tpaltitude     -0.18  -0.01  -0.01          0.00   0.02       1.00       0.23
# tplatitude     -0.76   0.00  -0.00         -0.00  -0.05       0.23       1.00
# tplongitude     0.01  -0.00   0.04          0.00  -0.13      -0.01      -0.00
# tpSolarZen     -0.12  -0.02  -0.03          0.03  -0.01       0.11       0.16
# ktemp          -0.32   0.01   0.00         -0.01   0.04       0.10       0.58
# dst_index      -0.00  -0.43  -0.45         -0.08   0.10       0.01       0.00
# ae_index        0.00   0.37   0.37          0.13  -0.06      -0.01      -0.01
# sym_h           0.00  -0.40  -0.43         -0.08   0.11       0.01      -0.00
# O3_density     -0.20   0.00   0.01         -0.01   0.03       0.15       0.31
#
#               tplongitude tpSolarZen  ktemp dst_index ae_index  sym_h  \
# event                0.01      -0.12  -0.32     -0.00     0.00   0.00
# solAp               -0.00      -0.02   0.01     -0.43     0.37  -0.40
# solKp                0.04      -0.03   0.00     -0.45     0.37  -0.43
# solf10p7Daily        0.00       0.03  -0.01     -0.08     0.13  -0.08
# time                -0.13      -0.01   0.04      0.10    -0.06   0.11
# tpaltitude          -0.01       0.11   0.10      0.01    -0.01   0.01
# tplatitude          -0.00       0.16   0.58      0.00    -0.01  -0.00
# tplongitude          1.00      -0.01  -0.05     -0.02    -0.01  -0.03
# tpSolarZen          -0.01       1.00   0.06      0.01    -0.01   0.01
# ktemp               -0.05       0.06   1.00      0.03    -0.02   0.03
# dst_index           -0.02       0.01   0.03      1.00    -0.65   0.98
# ae_index            -0.01      -0.01  -0.02     -0.65     1.00  -0.65
# sym_h               -0.03       0.01   0.03      0.98    -0.65   1.00
# O3_density          -0.00       0.11   0.38     -0.01    -0.01  -0.01
#
#               O3_density
# event              -0.20
# solAp               0.00
# solKp               0.01
# solf10p7Daily      -0.01
# time                0.03
# tpaltitude          0.15
# tplatitude          0.31
# tplongitude        -0.00
# tpSolarZen          0.11
# ktemp               0.38
# dst_index          -0.01
# ae_index           -0.01
# sym_h              -0.01
# O3_density          1.00

# %%
arr=np.array(L)
arr
# Out:
# array([[ 1.00000000e+00,  4.56829827e-03,  2.58033399e-03,
#         -2.03089638e-03,  6.32552082e-02, -1.76041629e-01,
#         -7.64144889e-01,  1.01112665e-02, -1.16240083e-01,
#         -3.19492505e-01, -3.00787565e-03,  1.70213424e-03,
#          1.46389554e-03, -1.97397150e-01],
#        [ 4.56829827e-03,  1.00000000e+00,  7.89505299e-01,
#         -1.64943045e-01, -2.60981331e-02, -8.09851875e-03,
#          8.73865180e-05, -3.46204890e-04, -2.11174295e-02,
#          1.01539428e-02, -4.26030999e-01,  3.65192418e-01,
#         -4.03628044e-01,  2.11488371e-03],
#        [ 2.58033399e-03,  7.89505299e-01,  1.00000000e+00,
#         -2.23203893e-01, -4.13323558e-02, -8.07767565e-03,
#         -1.64872749e-03,  4.21614985e-02, -2.72283285e-02,
#          3.69287672e-03, -4.52811756e-01,  3.74059798e-01,
#         -4.27251256e-01,  1.15771494e-02],
#        [-2.03089638e-03, -1.64943045e-01, -2.23203893e-01,
#          1.00000000e+00, -1.14867710e-03,  4.72124652e-03,
#         -5.01607575e-04,  4.21051573e-03,  3.36261844e-02,
#         -1.46281068e-02, -7.79003904e-02,  1.27907695e-01,
#         -8.37861501e-02, -1.40400551e-02],
#        [ 6.32552082e-02, -2.60981331e-02, -4.13323558e-02,
#         -1.14867710e-03,  1.00000000e+00,  1.63715764e-02,
#         -5.06923474e-02, -1.25012782e-01, -1.42234119e-02,
#          3.93782432e-02,  1.04318346e-01, -6.45231701e-02,
#          1.08900773e-01,  3.37324855e-02],
#        [-1.76041629e-01, -8.09851875e-03, -8.07767565e-03,
#          4.72124652e-03,  1.63715764e-02,  1.00000000e+00,
#          2.26156674e-01, -9.37456015e-03,  1.07733402e-01,
#          1.00513328e-01,  1.30466080e-02, -8.80948890e-03,
#          1.09093834e-02,  1.46064049e-01],
#        [-7.64144889e-01,  8.73865180e-05, -1.64872749e-03,
#         -5.01607575e-04, -5.06923474e-02,  2.26156674e-01,
#          1.00000000e+00, -4.86320155e-03,  1.64925024e-01,
#          5.77938640e-01,  4.02257074e-03, -1.38131633e-02,
#         -3.14593305e-03,  3.06653919e-01],
#        [ 1.01112665e-02, -3.46204890e-04,  4.21614985e-02,
#          4.21051573e-03, -1.25012782e-01, -9.37456015e-03,
#         -4.86320155e-03,  1.00000000e+00, -6.04117009e-03,
#         -4.79904465e-02, -2.25096149e-02, -1.16907689e-02,
#         -3.29059557e-02, -2.34585125e-03],
#        [-1.16240083e-01, -2.11174295e-02, -2.72283285e-02,
#          3.36261844e-02, -1.42234119e-02,  1.07733402e-01,
#          1.64925024e-01, -6.04117009e-03,  1.00000000e+00,
#          6.35601411e-02,  1.31939812e-02, -1.40209094e-02,
#          5.72678796e-03,  1.07394069e-01],
#        [-3.19492505e-01,  1.01539428e-02,  3.69287672e-03,
#         -1.46281068e-02,  3.93782432e-02,  1.00513328e-01,
#          5.77938640e-01, -4.79904465e-02,  6.35601411e-02,
#          1.00000000e+00,  3.06296274e-02, -1.81848868e-02,
#          3.00832659e-02,  3.76169743e-01],
#        [-3.00787565e-03, -4.26030999e-01, -4.52811756e-01,
#         -7.79003904e-02,  1.04318346e-01,  1.30466080e-02,
#          4.02257074e-03, -2.25096149e-02,  1.31939812e-02,
#          3.06296274e-02,  1.00000000e+00, -6.52793004e-01,
#          9.80015959e-01, -1.35759233e-02],
#        [ 1.70213424e-03,  3.65192418e-01,  3.74059798e-01,
#          1.27907695e-01, -6.45231701e-02, -8.80948890e-03,
#         -1.38131633e-02, -1.16907689e-02, -1.40209094e-02,
#         -1.81848868e-02, -6.52793004e-01,  1.00000000e+00,
#         -6.54228261e-01, -5.60345236e-03],
#        [ 1.46389554e-03, -4.03628044e-01, -4.27251256e-01,
#         -8.37861501e-02,  1.08900773e-01,  1.09093834e-02,
#         -3.14593305e-03, -3.29059557e-02,  5.72678796e-03,
#          3.00832659e-02,  9.80015959e-01, -6.54228261e-01,
#          1.00000000e+00, -1.20016603e-02],
#        [-1.97397150e-01,  2.11488371e-03,  1.15771494e-02,
#         -1.40400551e-02,  3.37324855e-02,  1.46064049e-01,
#          3.06653919e-01, -2.34585125e-03,  1.07394069e-01,
#          3.76169743e-01, -1.35759233e-02, -5.60345236e-03,
#         -1.20016603e-02,  1.00000000e+00]])

# %%
fig = plt.figure(figsize = (10,10))
sns.heatmap(arr, vmax = 1, square = False,xticklabels=list(Dic.values()), yticklabels=list(Dic.values()))
plt.show()

# %%
fig = plt.figure(figsize=(6, 3.2))

ax = fig.add_subplot(111)
ax.set_title('colorMap')
plt.imshow(Arr)
ax.set_aspect('equal')

cax = fig.add_axes([0.12, 0.1, 0.78, 0.8])
cax.get_xaxis().set_visible(False)
cax.get_yaxis().set_visible(False)
cax.patch.set_alpha(0)
cax.set_frame_on(False)
plt.colorbar(orientation='vertical')
plt.show()

# %%
fig = plt.figure(figsize = (13,13))
sb.heatmap(Arr, vmax = 1, square = False)
plt.show()

# %%
Arr.shape
# Out:
# (13, 13)
