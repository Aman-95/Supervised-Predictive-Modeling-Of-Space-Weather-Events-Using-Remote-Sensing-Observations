# %%
# Dataset             - Created by Taking all values in desired altitude range
# Data Points         - 64,88,453
# Objective Variable  - Density of O3
# Model               - Simple Artificial Neural Network With AutoEncoder

# %% [markdown]
# #**Importing Modules**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import files

import sklearn
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

import keras
import tensorflow as tf
from keras.layers import Dropout
from keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import BatchNormalization

# %% [markdown]
# #**Get files from drive**

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# Authenticate and create the PyDrive client
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Getting Data File Nov 2003
d1 = drive.CreateFile({'id':"1r6WVCmX-bC-OMfuKYiO0zinVMqnqefhJ"})
d1.GetContentFile('Nov 2003.csv')

# %%
# Getting Data File of Nov 2004
d2 = drive.CreateFile({'id':"1BEaJkaW9pwbhflTbrxMmmxpLAPryJi0j"})
d2.GetContentFile('Nov 2004.csv')

# %%
# Getting Data File of OCT 2003
d3 = drive.CreateFile({'id':"14qrxMXnZWjVdLIwipUR_-EHRZxccKsrH"})
d3.GetContentFile('Oct 2003.csv')

# %%
# Getting AutoEncoder File
d4 = drive.CreateFile({'id':"1OYcmdZskkzJDRduzrnXGSn-eht97BJNE"})   
d4.GetContentFile('AutoEncoder_5.h5')

# %% [markdown]
# # **Data Pre-processing**

# %%
# Reading Files and creating data frames
f1=pd.read_csv("Nov 2003.csv")
df1=pd.DataFrame(f1)
df1
# Out:
#          Unnamed: 0  Date  event  ...  sym_h    O3_density       col_den
# 0                 0     1      1  ...    -74  1.808541e+06  1.921766e+10
# 1                 1     1      1  ...    -74  1.807533e+06  1.921766e+10
# 2                 2     1      1  ...    -74  1.930575e+06  1.921766e+10
# 3                 3     1      1  ...    -73  2.382319e+06  1.921766e+10
# 4                 4     1      1  ...    -73  3.017615e+06  1.921766e+10
# ...             ...   ...    ...  ...    ...           ...           ...
# 2869668     2869675    30     98  ...    -33  6.591591e+08  1.226737e+10
# 2869669     2869676    30     98  ...    -33  8.297189e+08  1.226737e+10
# 2869670     2869677    30     98  ...    -33  1.105536e+09  1.226737e+10
# 2869671     2869678    30     98  ...    -33  1.673162e+09  1.226737e+10
# 2869672     2869679    30     98  ...    -33  2.495915e+09  1.226737e+10
#
# [2869673 rows x 20 columns]

# %%
# Reading Files and creating data frames
f2=pd.read_csv("Nov 2004.csv")
df2=pd.DataFrame(f2)
df2
# Out:
#          Unnamed: 0  Date  event  ...  sym_h    O3_density       col_den
# 0                 0     1      1  ...     -9  3.748935e+05  1.953871e+10
# 1                 1     1      1  ...     -9  4.165514e+05  1.953871e+10
# 2                 2     1      1  ...     -9  4.728989e+05  1.953871e+10
# 3                 3     1      1  ...     -9  5.426156e+05  1.953871e+10
# 4                 4     1      1  ...     -9  6.156787e+05  1.953871e+10
# ...             ...   ...    ...  ...    ...           ...           ...
# 3017503     3017503    30     96  ...     -6  1.933510e+08  8.241677e+09
# 3017504     3017504    30     96  ...     -6  3.107276e+08  8.241677e+09
# 3017505     3017505    30     96  ...     -6  5.843616e+08  8.241677e+09
# 3017506     3017506    30     96  ...     -6  1.182043e+09  8.241677e+09
# 3017507     3017507    30     96  ...     -6  2.154079e+09  8.241677e+09
#
# [3017508 rows x 20 columns]

# %%
# Reading Files and creating data frames
f3=pd.read_csv("Oct 2003.csv")
df3=pd.DataFrame(f3)
df3
# Out:
#         Unnamed: 0  Date  event  ...  sym_h    O3_density       col_den
# 0                0    26      1  ...    -30  2.553622e+06  1.516348e+10
# 1                1    26      1  ...    -30  3.085796e+06  1.516348e+10
# 2                2    26      1  ...    -30  3.753898e+06  1.516348e+10
# 3                3    26      1  ...    -30  3.461265e+06  1.516348e+10
# 4                4    26      1  ...    -30  5.661828e+06  1.516348e+10
# ...            ...   ...    ...  ...    ...           ...           ...
# 601267      601295    31     98  ...    -73  5.503687e+08  1.780777e+10
# 601268      601296    31     98  ...    -73  9.593660e+08  1.780777e+10
# 601269      601297    31     98  ...    -73  1.262374e+09  1.780777e+10
# 601270      601298    31     98  ...    -73  1.519708e+09  1.780777e+10
# 601271      601299    31     98  ...    -73  2.226402e+09  1.780777e+10
#
# [601272 rows x 20 columns]

# %%
# Merging Nov 2003 & Nov 2004 datasets
df =  pd.concat([df3,df1,df2])
df
# Out:
#          Unnamed: 0  Date  event  ...  sym_h    O3_density       col_den
# 0                 0    26      1  ...    -30  2.553622e+06  1.516348e+10
# 1                 1    26      1  ...    -30  3.085796e+06  1.516348e+10
# 2                 2    26      1  ...    -30  3.753898e+06  1.516348e+10
# 3                 3    26      1  ...    -30  3.461265e+06  1.516348e+10
# 4                 4    26      1  ...    -30  5.661828e+06  1.516348e+10
# ...             ...   ...    ...  ...    ...           ...           ...
# 3017503     3017503    30     96  ...     -6  1.933510e+08  8.241677e+09
# 3017504     3017504    30     96  ...     -6  3.107276e+08  8.241677e+09
# 3017505     3017505    30     96  ...     -6  5.843616e+08  8.241677e+09
# 3017506     3017506    30     96  ...     -6  1.182043e+09  8.241677e+09
# 3017507     3017507    30     96  ...     -6  2.154079e+09  8.241677e+09
#
# [6488453 rows x 20 columns]

# %%
x_col=["Date","solAp","solf10p7Daily","time","tpaltitude","tplatitude","tplongitude","tpSolarZen","ktemp","ae_index","dst_index"]  # "event","sym_h" , "solKp"
y_col=["O3_density"]

# %%
x=pd.DataFrame(columns=x_col)
y=pd.DataFrame(columns=y_col)
for i in x_col:
  x[i]=df[i]

for i in y_col:
  y[i]=df[i]

x
# Out:
#          Date  solAp  solf10p7Daily  ...       ktemp  ae_index  dst_index
# 0          26   10.0          243.4  ...  276.386414        56        -31
# 1          26   10.0          243.4  ...  259.460693        56        -31
# 2          26   10.0          243.4  ...  233.853317        56        -31
# 3          26   10.0          243.4  ...  207.674591        56        -31
# 4          26   10.0          243.4  ...  187.036041        56        -31
# ...       ...    ...            ...  ...         ...       ...        ...
# 3017503    30   17.0          111.4  ...  211.435822       113         -5
# 3017504    30   17.0          111.4  ...  214.712189       113         -5
# 3017505    30   17.0          111.4  ...  213.038940       113         -5
# 3017506    30   17.0          111.4  ...  204.414856       113         -5
# 3017507    30   17.0          111.4  ...  197.334351       113         -5
#
# [6488453 rows x 11 columns]

# %%
y
# Out:
#            O3_density
# 0        2.553622e+06
# 1        3.085796e+06
# 2        3.753898e+06
# 3        3.461265e+06
# 4        5.661828e+06
# ...               ...
# 3017503  1.933510e+08
# 3017504  3.107276e+08
# 3017505  5.843616e+08
# 3017506  1.182043e+09
# 3017507  2.154079e+09
#
# [6488453 rows x 1 columns]

# %%
# Random Train-Test Split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.05, random_state = 0)

# %%
# Data Scaling
'''# Standard Scaling
sc_x = StandardScaler()
sc_y = StandardScaler()'''

# Min-Max Scaling
sc_x = MinMaxScaler()
sc_y =  MinMaxScaler()

x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)

y_train = sc_y.fit_transform(y_train)
y_test = sc_y.transform(y_test)

# %%
# Convert the input datapoints to encoded using the Encoder part of AUTO-ENCODER

# load the model from file
autoencoder = load_model('AutoEncoder_5.h5')

# encode the train & test data
x_train_encoded = autoencoder.predict(x_train)
x_test_encoded = autoencoder.predict(x_test)

# %%
print("x_train_encoded:\n",x_train_encoded)
print("\nx_test_encoded:\n",x_test_encoded)
# Out:
# x_train_encoded:
#  [[0.18767458 0.05891269 0.19704291 ... 0.37650487 0.07186136 0.8321465 ]
#  [0.41194516 0.05899504 0.0907681  ... 0.3745536  0.06090462 0.823635  ]
#  [0.33920133 0.09503078 0.06889588 ... 0.40213692 0.07340875 0.8124017 ]
#  ...
#  [0.526545   0.07962751 0.13500097 ... 0.39177254 0.06917048 0.8056692 ]
#  [0.19615066 0.1369465  0.20057404 ... 0.39685798 0.1025658  0.77041614]
#  [0.35830146 0.86835647 0.06109753 ... 0.41472378 0.17574775 0.5889776 ]]
#
# x_test_encoded:
#  [[0.48566684 0.11448884 0.13758945 ... 0.39903447 0.08098301 0.7837124 ]
#  [0.22930908 0.09984118 0.15046763 ... 0.39416873 0.08171287 0.7959345 ]
#  [0.37852207 0.06847548 0.04117382 ... 0.3921788  0.06816515 0.8274202 ]
#  ...
#  [0.1680961  0.09446189 0.23009211 ... 0.39357617 0.07530159 0.8092525 ]
#  [0.8059685  0.08505553 0.3512651  ... 0.39752585 0.06186724 0.80659306]
#  [0.15182412 0.07064116 0.27234542 ... 0.3776031  0.06929749 0.8348794 ]]

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
print(x_train_encoded.shape)
print(x_test_encoded.shape)
# Out:
# (6164030, 11)
# (324423, 11)
# (6164030, 1)
# (324423, 1)
# (6164030, 11)
# (324423, 11)

# %% [markdown]
# #**Model Building and Training**

# %%
# parameters
dfr=0.1    # Droput fracton
neu_in=x_train.shape[1]     # Input layers
neu_out=1  # Output layers
hl=8       # Hidden layers
neu=64     # No. of Neurons
bsz=128     # Batch Size
epc=20     # Epochs 
lss="mse"  # Loss function
#  Evaluation Matrix
mtx= [tf.keras.metrics.MeanSquaredError(),tf.keras.metrics.MeanAbsoluteError(),tf.keras.metrics.RootMeanSquaredError()]
vld_splt=0.11

# %%
model=Sequential()

model.add(Dense(neu, input_dim = neu_in))    # Adding the input layer and the first hidden layer
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(Dropout(dfr))

for i in range(hl):                                            # Adding the inner hidden layers
  model.add(Dense(neu))
  model.add(BatchNormalization())
  model.add(LeakyReLU())
  model.add(Dropout(dfr))

model.add(Dense(neu_out, activation = 'sigmoid'))                   # Adding the output layer

# %%
# Compiling the model   
model.compile(optimizer = 'adam', loss = lss, metrics = mtx)

# %%
# Training the model
res=model.fit(x_train_encoded, y_train,validation_data=(x_test_encoded,y_test),validation_split=vld_splt,batch_size = bsz, epochs = epc)
# Out:
# Epoch 1/20
# 42860/42860 [==============================] - 343s 7ms/step - loss: 0.0027 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0393 - root_mean_squared_error: 0.0674 - val_loss: 4.5890e-04 - val_mean_squared_error: 0.0011 - val_mean_absolute_error: 0.0164 - val_root_mean_squared_error: 0.0337
# Epoch 2/20
# 42860/42860 [==============================] - 316s 7ms/step - loss: 7.3646e-04 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0157 - root_mean_squared_error: 0.0322 - val_loss: 4.4916e-04 - val_mean_squared_error: 9.0792e-04 - val_mean_absolute_error: 0.0147 - val_root_mean_squared_error: 0.0301
# Epoch 3/20
# 42860/42860 [==============================] - 316s 7ms/step - loss: 6.9815e-04 - mean_squared_error: 8.7693e-04 - mean_absolute_error: 0.0145 - root_mean_squared_error: 0.0296 - val_loss: 4.1340e-04 - val_mean_squared_error: 8.2377e-04 - val_mean_absolute_error: 0.0141 - val_root_mean_squared_error: 0.0287
# Epoch 4/20
# 42860/42860 [==============================] - 310s 7ms/step - loss: 6.6996e-04 - mean_squared_error: 8.0666e-04 - mean_absolute_error: 0.0139 - root_mean_squared_error: 0.0284 - val_loss: 4.0524e-04 - val_mean_squared_error: 7.7681e-04 - val_mean_absolute_error: 0.0137 - val_root_mean_squared_error: 0.0279
# Epoch 5/20
# 42860/42860 [==============================] - 314s 7ms/step - loss: 6.6010e-04 - mean_squared_error: 7.6606e-04 - mean_absolute_error: 0.0136 - root_mean_squared_error: 0.0277 - val_loss: 4.1136e-04 - val_mean_squared_error: 7.4664e-04 - val_mean_absolute_error: 0.0135 - val_root_mean_squared_error: 0.0273
# Epoch 6/20
# 42860/42860 [==============================] - 318s 7ms/step - loss: 6.4753e-04 - mean_squared_error: 7.3902e-04 - mean_absolute_error: 0.0134 - root_mean_squared_error: 0.0272 - val_loss: 4.1268e-04 - val_mean_squared_error: 7.2515e-04 - val_mean_absolute_error: 0.0133 - val_root_mean_squared_error: 0.0269
# Epoch 7/20
# 42860/42860 [==============================] - 316s 7ms/step - loss: 6.4005e-04 - mean_squared_error: 7.1937e-04 - mean_absolute_error: 0.0132 - root_mean_squared_error: 0.0268 - val_loss: 4.2849e-04 - val_mean_squared_error: 7.0918e-04 - val_mean_absolute_error: 0.0132 - val_root_mean_squared_error: 0.0266
# Epoch 8/20
# 42860/42860 [==============================] - 314s 7ms/step - loss: 6.3359e-04 - mean_squared_error: 7.0479e-04 - mean_absolute_error: 0.0131 - root_mean_squared_error: 0.0265 - val_loss: 3.8424e-04 - val_mean_squared_error: 6.9634e-04 - val_mean_absolute_error: 0.0130 - val_root_mean_squared_error: 0.0264
# Epoch 9/20
# 42860/42860 [==============================] - 314s 7ms/step - loss: 6.2681e-04 - mean_squared_error: 6.9245e-04 - mean_absolute_error: 0.0130 - root_mean_squared_error: 0.0263 - val_loss: 3.7231e-04 - val_mean_squared_error: 6.8540e-04 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0262
# Epoch 10/20
# 42860/42860 [==============================] - 313s 7ms/step - loss: 6.2123e-04 - mean_squared_error: 6.8203e-04 - mean_absolute_error: 0.0129 - root_mean_squared_error: 0.0261 - val_loss: 4.2888e-04 - val_mean_squared_error: 6.7629e-04 - val_mean_absolute_error: 0.0129 - val_root_mean_squared_error: 0.0260
# Epoch 11/20
# 42860/42860 [==============================] - 322s 8ms/step - loss: 6.1786e-04 - mean_squared_error: 6.7371e-04 - mean_absolute_error: 0.0128 - root_mean_squared_error: 0.0260 - val_loss: 4.1776e-04 - val_mean_squared_error: 6.6902e-04 - val_mean_absolute_error: 0.0128 - val_root_mean_squared_error: 0.0259
# Epoch 12/20
# 42860/42860 [==============================] - 323s 8ms/step - loss: 6.1296e-04 - mean_squared_error: 6.6673e-04 - mean_absolute_error: 0.0128 - root_mean_squared_error: 0.0258 - val_loss: 3.8190e-04 - val_mean_squared_error: 6.6246e-04 - val_mean_absolute_error: 0.0127 - val_root_mean_squared_error: 0.0257
# Epoch 13/20
# 42860/42860 [==============================] - 295s 7ms/step - loss: 6.0807e-04 - mean_squared_error: 6.6018e-04 - mean_absolute_error: 0.0127 - root_mean_squared_error: 0.0257 - val_loss: 4.8879e-04 - val_mean_squared_error: 6.5694e-04 - val_mean_absolute_error: 0.0127 - val_root_mean_squared_error: 0.0256
# Epoch 14/20
# 42860/42860 [==============================] - 297s 7ms/step - loss: 6.0780e-04 - mean_squared_error: 6.5547e-04 - mean_absolute_error: 0.0127 - root_mean_squared_error: 0.0256 - val_loss: 4.4386e-04 - val_mean_squared_error: 6.5236e-04 - val_mean_absolute_error: 0.0126 - val_root_mean_squared_error: 0.0255
# Epoch 15/20
# 42860/42860 [==============================] - 296s 7ms/step - loss: 6.0844e-04 - mean_squared_error: 6.5091e-04 - mean_absolute_error: 0.0126 - root_mean_squared_error: 0.0255 - val_loss: 4.1602e-04 - val_mean_squared_error: 6.4789e-04 - val_mean_absolute_error: 0.0126 - val_root_mean_squared_error: 0.0255
# Epoch 16/20
# 42860/42860 [==============================] - 296s 7ms/step - loss: 6.0482e-04 - mean_squared_error: 6.4638e-04 - mean_absolute_error: 0.0126 - root_mean_squared_error: 0.0254 - val_loss: 4.7268e-04 - val_mean_squared_error: 6.4405e-04 - val_mean_absolute_error: 0.0126 - val_root_mean_squared_error: 0.0254
# Epoch 17/20
# 42860/42860 [==============================] - 297s 7ms/step - loss: 6.0540e-04 - mean_squared_error: 6.4300e-04 - mean_absolute_error: 0.0126 - root_mean_squared_error: 0.0254 - val_loss: 4.1711e-04 - val_mean_squared_error: 6.4053e-04 - val_mean_absolute_error: 0.0125 - val_root_mean_squared_error: 0.0253
# Epoch 18/20
# 42860/42860 [==============================] - 297s 7ms/step - loss: 5.9902e-04 - mean_squared_error: 6.3936e-04 - mean_absolute_error: 0.0125 - root_mean_squared_error: 0.0253 - val_loss: 4.5714e-04 - val_mean_squared_error: 6.3727e-04 - val_mean_absolute_error: 0.0125 - val_root_mean_squared_error: 0.0252
# Epoch 19/20
# 42860/42860 [==============================] - 299s 7ms/step - loss: 5.9575e-04 - mean_squared_error: 6.3624e-04 - mean_absolute_error: 0.0125 - root_mean_squared_error: 0.0252 - val_loss: 4.4310e-04 - val_mean_squared_error: 6.3426e-04 - val_mean_absolute_error: 0.0125 - val_root_mean_squared_error: 0.0252
# Epoch 20/20
# 42860/42860 [==============================] - 298s 7ms/step - loss: 5.9538e-04 - mean_squared_error: 6.3332e-04 - mean_absolute_error: 0.0125 - root_mean_squared_error: 0.0252 - val_loss: 4.0272e-04 - val_mean_squared_error: 6.3139e-04 - val_mean_absolute_error: 0.0124 - val_root_mean_squared_error: 0.0251

# %% [markdown]
# #**Model Saving**

# %%
# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper (ModuleWrappe (None, 64)                768
# _________________________________________________________________
# module_wrapper_1 (ModuleWrap (None, 64)                256
# _________________________________________________________________
# module_wrapper_2 (ModuleWrap (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# module_wrapper_3 (ModuleWrap (None, 64)                4160
# _________________________________________________________________
# module_wrapper_4 (ModuleWrap (None, 64)                256
# _________________________________________________________________
# module_wrapper_5 (ModuleWrap (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# module_wrapper_6 (ModuleWrap (None, 64)                4160
# _________________________________________________________________
# module_wrapper_7 (ModuleWrap (None, 64)                256
# _________________________________________________________________
# module_wrapper_8 (ModuleWrap (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# module_wrapper_9 (ModuleWrap (None, 64)                4160
# _________________________________________________________________
# module_wrapper_10 (ModuleWra (None, 64)                256
# _________________________________________________________________
# module_wrapper_11 (ModuleWra (None, 64)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# module_wrapper_12 (ModuleWra (None, 64)                4160
# _________________________________________________________________
# module_wrapper_13 (ModuleWra (None, 64)                256
# _________________________________________________________________
# module_wrapper_14 (ModuleWra (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# module_wrapper_15 (ModuleWra (None, 64)                4160
# _________________________________________________________________
# module_wrapper_16 (ModuleWra (None, 64)                256
# _________________________________________________________________
# module_wrapper_17 (ModuleWra (None, 64)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# module_wrapper_18 (ModuleWra (None, 64)                4160
# _________________________________________________________________
# module_wrapper_19 (ModuleWra (None, 64)                256
# _________________________________________________________________
# module_wrapper_20 (ModuleWra (None, 64)                0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# module_wrapper_21 (ModuleWra (None, 64)                4160
# _________________________________________________________________
# module_wrapper_22 (ModuleWra (None, 64)                256
# _________________________________________________________________
# module_wrapper_23 (ModuleWra (None, 64)                0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# module_wrapper_24 (ModuleWra (None, 64)                4160
# _________________________________________________________________
# module_wrapper_25 (ModuleWra (None, 64)                256
# _________________________________________________________________
# module_wrapper_26 (ModuleWra (None, 64)                0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# module_wrapper_27 (ModuleWra (None, 1)                 65
# =================================================================
# Total params: 36,417
# Trainable params: 35,265
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
# Save and Download Model
model.save("model_NN_7")
#files.download('model_NN_7')
# Out:
# WARNING:absl:Found untraced functions such as dense_layer_call_and_return_conditional_losses, dense_layer_call_fn, leaky_re_lu_layer_call_and_return_conditional_losses, leaky_re_lu_layer_call_fn, dense_1_layer_call_and_return_conditional_losses while saving (showing 5 of 95). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_NN_7/assets
# INFO:tensorflow:Assets written to: model_NN_7/assets

# %%
# Training History
res.history
# Out:
# {'loss': [0.0011775799794122577,
#   0.0007219146937131882,
#   0.0006885019829496741,
#   0.00066694914130494,
#   0.0006548181991092861,
#   0.0006443543243221939,
#   0.0006383256986737251,
#   0.000631922681350261,
#   0.0006256671040318906,
#   0.0006190064013935626,
#   0.0006181285134516656,
#   0.0006141792982816696,
#   0.0006102002807892859,
#   0.000608793692663312,
#   0.0006046454655006528,
#   0.0006041579181328416,
#   0.0006016517872922122,
#   0.0005998569540679455,
#   0.0005964754382148385,
#   0.0005958536057732999],
#  'mean_absolute_error': [0.024149492383003235,
#   0.015368279069662094,
#   0.014367537572979927,
#   0.013882136903703213,
#   0.013582122512161732,
#   0.013369912281632423,
#   0.013215050101280212,
#   0.013097959570586681,
#   0.012992989271879196,
#   0.012904610484838486,
#   0.012828975915908813,
#   0.012765400111675262,
#   0.012706571258604527,
#   0.012665041722357273,
#   0.012624694965779781,
#   0.01258057914674282,
#   0.012551452964544296,
#   0.012516966089606285,
#   0.012489317916333675,
#   0.012458490207791328],
#  'mean_squared_error': [0.00273089949041605,
#   0.000994267174974084,
#   0.0008606957271695137,
#   0.0007978408830240369,
#   0.0007607177249155939,
#   0.0007352646789513528,
#   0.0007165686693042517,
#   0.0007026965031400323,
#   0.0006907352362759411,
#   0.0006805465091019869,
#   0.0006725806160829961,
#   0.0006657025078311563,
#   0.0006592233548872173,
#   0.0006548071396537125,
#   0.0006501646130345762,
#   0.0006456306437030435,
#   0.0006423902814276516,
#   0.0006389541085809469,
#   0.0006357562378980219,
#   0.0006328955059871078],
#  'root_mean_squared_error': [0.04657667130231857,
#   0.031521640717983246,
#   0.029335156083106995,
#   0.028245454654097557,
#   0.02758391760289669,
#   0.02711271122097969,
#   0.026776134967803955,
#   0.026512421667575836,
#   0.026283379644155502,
#   0.026082102209329605,
#   0.025933245196938515,
#   0.025800662115216255,
#   0.025676675140857697,
#   0.025584561750292778,
#   0.025504669174551964,
#   0.02540736272931099,
#   0.025340920314192772,
#   0.025273920968174934,
#   0.025209644809365273,
#   0.025153815746307373],
#  'val_loss': [0.00045890422188676894,
#   0.0004491595318540931,
#   0.00041339502786286175,
#   0.00040524190990254283,
#   0.0004113640170544386,
#   0.00041268250788562,
#   0.00042849339661188424,
#   0.00038423985824920237,
#   0.0003723101981449872,
#   0.00042887890595011413,
#   0.0004177603404968977,
#   0.0003818954573944211,
#   0.0004887947579845786,
#   0.00044385925866663456,
#   0.0004160186508670449,
#   0.0004726832266896963,
#   0.0004171074542682618,
#   0.00045714134466834366,
#   0.00044309740769676864,
#   0.0004027151153422892],
#  'val_mean_absolute_error': [0.01639719307422638,
#   0.01473306491971016,
#   0.014086048118770123,
#   0.013713947497308254,
#   0.013468045741319656,
#   0.013288704678416252,
#   0.013153410516679287,
#   0.013041633181273937,
#   0.01294649951159954,
#   0.012866920791566372,
#   0.012800064869225025,
#   0.012740190140902996,
#   0.012688341550529003,
#   0.01264488510787487,
#   0.012602390721440315,
#   0.012567303143441677,
#   0.012534798122942448,
#   0.012503939680755138,
#   0.01247545424848795,
#   0.012448565103113651],
#  'val_mean_squared_error': [0.0011365064419806004,
#   0.0009079160518012941,
#   0.0008237689617089927,
#   0.0007768072537146509,
#   0.0007466445676982403,
#   0.0007251450442709029,
#   0.0007091817096807063,
#   0.0006963415071368217,
#   0.000685397710185498,
#   0.0006762912380509079,
#   0.0006690233130939305,
#   0.0006624649977311492,
#   0.0006569448160007596,
#   0.0006523639895021915,
#   0.000647890439722687,
#   0.000644045474473387,
#   0.0006405338062904775,
#   0.0006372670759446919,
#   0.0006342643173411489,
#   0.0006313864723779261],
#  'val_root_mean_squared_error': [0.03371036797761917,
#   0.030131395906209946,
#   0.028701301664114,
#   0.02787129208445549,
#   0.02732476405799389,
#   0.02692851610481739,
#   0.026630783453583717,
#   0.026388367637991905,
#   0.026180163025856018,
#   0.026005979627370834,
#   0.025865882635116577,
#   0.02573820948600769,
#   0.02563086897134781,
#   0.025541573762893677,
#   0.025453554466366768,
#   0.025377590209245682,
#   0.025308901444077492,
#   0.025244558230042458,
#   0.025184746831655502,
#   0.02512722834944725]}

# %% [markdown]
# # **Predictions**

# %%
# Predictions
y_pred=model.predict(x_test_encoded)
#y_test = sc_y.transform(y_test)

# %%
# Error Calculation in Testing Data
mse = np.mean(tf.keras.losses.mean_squared_error(y_test, y_pred))
mae = np.mean(tf.keras.losses.mean_absolute_error(y_test,y_pred))
#mape = np.mean(tf.keras.losses.mean_absolute_percentage_error(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
print("Mean Squared Error: ",mse)
print("Mean Absolute Error: ",mae)
#print("Mean Absolute Percentage Error: ",mape)
print("R2 Score: ",r2)
# Out:
# Mean Squared Error:  0.00040646608
# Mean Absolute Error:  0.00939836
# R2 Score:  0.896880627308005

# %% [markdown]
# # **Plots**

# %%
res.history.keys()
# Out:
# dict_keys(['loss', 'mean_squared_error', 'mean_absolute_error', 'root_mean_squared_error', 'val_loss', 'val_mean_squared_error', 'val_mean_absolute_error', 'val_root_mean_squared_error'])

# %%
Lt=[]
Lv=[]
for i in res.history['loss']:
  Lt.append(i)
for i in res.history['val_loss']:
  Lv.append(i)
plt.plot(Lt)
plt.plot(Lv)
plt.title('loss plot')
plt.ylabel('loss')
plt.xlabel('Epochs')
plt.legend(['train','test'],loc='upper right')
plt.show()

# %%
Lt=[]
Lv=[]
for i in res.history['mean_squared_error']:
  Lt.append(i)
for i in res.history['val_mean_squared_error']:
  Lv.append(i)
plt.plot(Lt)
plt.plot(Lv)
plt.title('MSE plot')
plt.ylabel('MSE')
plt.xlabel('Epochs')
plt.legend(['train','test'],loc='upper right')
plt.show()

plt.plot(Lt)
plt.plot(Lv)
plt.title('MSE plot')
plt.ylabel('MSE')
plt.xlabel('Epochs')
plt.legend(['train','test'],loc='upper right')
plt.plot(epc-1,mse,"rD")
plt.annotate("  On Test Data",(epc-1,mse))
plt.show()

# %%
Lt=[]
Lv=[]
for i in res.history['mean_absolute_error']:
  Lt.append(i)
for i in res.history['val_mean_absolute_error']:
  Lv.append(i)
plt.plot(Lt)
plt.plot(Lv)
plt.title('MAE plot')
plt.ylabel('MAE')
plt.xlabel('Epochs')
plt.legend(['train','test'],loc='upper right')
plt.show()

plt.plot(Lt)
plt.plot(Lv)
plt.title('MAE plot')
plt.ylabel('MAE')
plt.xlabel('Epochs')
plt.legend(['train','test'],loc='upper right')
plt.plot(epc-1,mae,"rD")
plt.annotate("  On Test Data",(epc-1,mae))
plt.show()

# %%
Lt=[]
Lv=[]
for i in res.history['root_mean_squared_error']:
  Lt.append(i)
for i in res.history['val_root_mean_squared_error']:
  Lv.append(i)
plt.plot(Lt)
plt.plot(Lv)
plt.title('RMSE plot')
plt.ylabel('RMSE')
plt.xlabel('Epochs')
plt.legend(['train','test'],loc='upper right')
plt.show()

# %% [markdown]
# #**Results**

# %%
# Inverse transporm to Undo Scaling
y_pred=sc_y.inverse_transform(y_pred)
y_test=sc_y.inverse_transform(y_test)

# %%
# Predicted v/s Actual Values Plot
plt.plot(y_test,y_pred,'.')
plt.title("Actual v/s Predicted Values")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")

a = np.linspace(-3e9,8e9, 100) 
b = a 
plt.plot(a,b,"red")
plt.show()

# %%
# R-squared Value
r=r2_score(y_test, y_pred)
print(r)
# Out:
# 0.8968806272872973

# %%
x = np.linspace(-20, 50, 100000)
for i in range(0,2000,50):
  plt.plot(y_pred, color='blue')
  plt.plot(y_test, color='red')
  plt.ylabel("O3 Density")
  plt.xlim([i,i+50])
  plt.legend(['predicted','test'],loc='upper right')
  plt.show()

# %%
x = np.linspace(-20, 50, 100000)
step = 100
for i in range(0,2000,step):
  plt.plot(y_pred, color='blue')
  plt.plot(y_test, color='red')
  plt.ylabel("O3 Density")
  plt.xlim([i,i+step])
  plt.legend(['predicted','test'],loc='upper right')
  plt.show()

# %%
l=range(len(y_pred))

plt.plot(l,y_test,'.',label="y_test")
plt.plot(l,y_pred,'.',label="y_pred")
plt.ylabel("O3 Density")
plt.legend()
plt.show()

# %% [markdown]
# # **Testing Model On Oct 2003 Data**

# %%
X=pd.DataFrame(columns=x_col)
Y=pd.DataFrame(columns=y_col)
for i in x_col:
  X[i]=df3[i]

for i in y_col:
  Y[i]=df3[i]

X
# Out:
#         Date  solAp  solf10p7Daily  ...       ktemp  ae_index  dst_index
# 0         26   10.0          243.4  ...  276.386414        56        -31
# 1         26   10.0          243.4  ...  259.460693        56        -31
# 2         26   10.0          243.4  ...  233.853317        56        -31
# 3         26   10.0          243.4  ...  207.674591        56        -31
# 4         26   10.0          243.4  ...  187.036041        56        -31
# ...      ...    ...            ...  ...         ...       ...        ...
# 601267    31  116.0          248.9  ...  207.508942       609        -69
# 601268    31  116.0          248.9  ...  206.174927       609        -69
# 601269    31  116.0          248.9  ...  209.336380       609        -69
# 601270    31  116.0          248.9  ...  211.722443       609        -69
# 601271    31  116.0          248.9  ...  209.204468       609        -69
#
# [601272 rows x 11 columns]

# %%
Y
# Out:
#           O3_density
# 0       2.553622e+06
# 1       3.085796e+06
# 2       3.753898e+06
# 3       3.461265e+06
# 4       5.661828e+06
# ...              ...
# 601267  5.503687e+08
# 601268  9.593660e+08
# 601269  1.262374e+09
# 601270  1.519708e+09
# 601271  2.226402e+09
#
# [601272 rows x 1 columns]

# %%
X, _ , Y , __ = train_test_split(X, Y, test_size = 0.1, random_state = 0)

# %%
# Scaling
X = sc_x.transform(X)
Y = sc_y.transform(Y)

# %%
X = autoencoder.predict(X)

# %%
Y_Pred=model.predict(X)

# %%
# Error Calculation in Testing Data
mse = np.mean(tf.keras.losses.mean_squared_error(Y, Y_Pred))
mae = np.mean(tf.keras.losses.mean_absolute_error(Y, Y_Pred))
r2 = r2_score(Y, Y_Pred)
print("Mean Squared Error: ",mse)
print("Mean Absolute Error: ",mae)
print("R2 Score: ",r2)
# Out:
# Mean Squared Error:  0.00046991816
# Mean Absolute Error:  0.011246124
# R2 Score:  0.8869877608238212

# %%
# Inverse transporm to Undo Scaling
Y=sc_y.inverse_transform(Y)
Y_Pred=sc_y.inverse_transform(Y_Pred)

# %%
# Predicted v/s Actual Values Plot
plt.plot(Y,Y_Pred,'.')
plt.title("Actual v/s Predicted Values")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")

a = np.linspace(-4e9,8e9, 100)
b = a 
plt.plot(a,b,"red")
plt.show()

# %%
x = np.linspace(-20, 50, 100000)
step = 50
for i in range(0,2000,step):
  plt.plot(Y_Pred, color='blue')
  plt.plot(Y, color='red')
  plt.xlim([i,i+step])
  plt.ylabel("O3 Density")
  plt.legend(['predicted','test'],loc='upper right')
  plt.show()

# %%
x = np.linspace(-20, 50, 100000)
step=100
for i in range(0,2000,step):
  plt.plot(Y_Pred, color='blue')
  plt.plot(Y, color='red')
  plt.xlim([i,i+step])
  plt.ylabel("O3 Density")
  plt.legend(['predicted','test'],loc='upper right')
  plt.show()

# %%
l=range(len(Y_Pred))

plt.plot(l,Y,'.',label="y_test")
plt.plot(l,Y_Pred,'.',label="y_pred")
plt.ylabel("O3 Density")
plt.legend()
plt.show()
